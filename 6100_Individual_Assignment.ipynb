# %%
#####Name: Wang Jingyi
#####Matriculation No:G2000751D
#####Assignment:AN6100 individual assignment
#####This is a validation of visa card number program

#Question 1
def LastDigit(cardno):
    #receive a standard 16 digits Visa Card string and get the last element 
    #return the lastdigit as an int number
    lastdigit=int(cardno[-1])
    return lastdigit

#Question 2
import re
def First15DReverseList(cardno):
    #use "\D" to match any non-numeric element in the carno string
    #use re.sub to replace non-numeric element with "" in the carno string,thus would return a string only with numbers 
    First15DReverse=re.sub("\D","",cardno)
    #map help call the int function,and would return an int element for each one in the string
    #list help transfer the string into a list
    First15DReverse=list(map(int,First15DReverse))
    #pop would remove the last element in the list
    First15DReverse.pop()
    #reverse the list
    First15DReverse.reverse()
    return First15DReverse


#Question 3
def x2ToOddDigits(inlist):
    #create a new list 
    #x in enumerate() would be an iterator to multiply the digits by 2
    #i in enumerate() is the index starts from 0,thus i%2==0 satisfies condition of in odd positions
    list=[x*2 if i%2==0 else x for i,x in enumerate(inlist)]
    #clear the inlist
    inlist.clear()
    #extend the inlist with new list
    inlist.extend(list)
    return None


#Question 4
def normalise9(inlist):
    #prepare a new list,subtract 9 to any element if it is higher than 9
    normalis9=[i-9 if i>9 else i for i in inlist]
    #return the new list to the caller
    return normalis9


#Question 5
def findlastdigit(norm15Dlist):
    # sum all the numbers in the list
    #return the remainder when divided by 10
    #10 minus the remainder to get the number I need to get a multiple of 10
    findlastdig=10-(sum(norm15Dlist)%10)
    return findlastdig



#Question 6
def validateVisa(cardno):
    #call LastDigit function to get the check digit from the Credit Card number
    checkdigit=LastDigit(cardno)
    #The Luhn Formula:

    #call First15DReverseList function to drop the last digit of the 16-digit-card numbers,then reverse the numbers
    cardno=First15DReverseList(cardno)
    #call the x2ToOddDigits function to multiply the digits in odd positions
    x2ToOddDigits(cardno)
    #call the normalise9 function to subtract 9 to all any result higher than 9
    cardno=normalise9(cardno)
    #call the findlastdigit function to add all the numbers together,get the number I need to get a multiple of 10
    validlastdigit=findlastdigit(cardno)
    #if the check digit is equal to validlastdigit,return True, else return false
    if checkdigit==validlastdigit:return True
    else: return False

if __name__ == "__main__":
  
  #Test for Question 1   
    print(1)
    print(LastDigit("4566-7375-8689-9855"))   #  should return 5
    print(LastDigit("4566-7375-8689-9857"))   #  should return 7

 
    #Test for Question 2
    print(2)
    revlist=First15DReverseList("4566-7375-8689-9855")
    print(revlist) # should return [5, 8, 9, 9, 8, 6, 8, 5, 7, 3, 7, 6, 6, 5, 4]
   
    #Test for Question 3
    print(3)
    klist=[5, 8, 9, 9, 8, 6, 8, 5, 7, 3, 7, 6, 6, 5, 4]
    x2ToOddDigits(klist)
    print(klist) # should return [10, 8, 18, 9, 16, 6, 16, 5, 14, 3, 14, 6, 12, 5, 8]

    #Test for Question 4
    print(4)
    finList =  normalise9([10, 8, 18, 9, 16, 6, 16, 5, 14, 3, 14, 6, 10, 5, 8])
    print(revlist) # should retuen [5, 8, 9, 9, 8, 6, 8, 5, 7, 3, 7, 6, 6, 5, 4]
    print(finList) # should return [1, 8, 9, 9, 7, 6, 7, 5, 5, 3, 5, 6, 1, 5, 8]

    #Test for Question 5
    print(5)
    print(findlastdigit([2,2,6,4,1,6])) #should print 9
    print(findlastdigit([9,2,6,4,1,6])) #should print 2   


    print("This is a test for validateVisa....")
    OrignalVisa="4556-7375-8689-9855"
    if validateVisa( OrignalVisa):
        print(f'{OrignalVisa} is a Valid Card')    # This should be printed
    else:
        print(f'{OrignalVisa} is a Invalid Card')
    anotherVisa= "4566-7375-8689-9855"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
    anotherVisa= "1230-5678-9012-3449"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')   # This should be printed
    else:
        print(f'{anotherVisa} is a Invalid Card')  
    anotherVisa= "1231-5678-9012-3449"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
    anotherVisa= "1232-5678-9012-3449"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
    anotherVisa= "1233-5678-9012-3449"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
    anotherVisa= "1234-5678-9012-3449"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
    anotherVisa= "1235-5678-9012-3449"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
    anotherVisa= "1236-5678-9012-3449"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
    anotherVisa= "1237-5678-9012-3449"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
    anotherVisa= "1238-5678-9012-3449"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
    anotherVisa= "1239-5678-9012-3449"
    if validateVisa(anotherVisa):  
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
""" 
    You may move this line down to perform testing after complete each function  
"""



"""
Todo:
1. Rename this file, change YourStudentID to your student number or your name, for example A3_1418412A.
2. You are required to complete the functions as per question, the instructions of each functions are written
as comment within the function, you are reminded to amend the return values whenever is required by the instructions
3. You are given some test data with command calling the function and the expected results in the main program
for your own testing
4. You will be graded based on the correct output with additional test cases that are prepared by the guider
5. You will also be graded on the quality of code, in terms of readability (so please insert comment when required),
efficiency and maintainability.
6, You are only required to submit this file for assignment 3
"""
#This is a validation of visa card number program

#Question 1
def LastDigit(cardno):
    """ Question 1 instructions
          This function will receive a 16 digits Visa Card Numbers delimited by - with 4 numberic numbers
          in between, you may assume the format 9999-9999-9999-999 has been validated before it is sent in
          This function will return the last numeric digit as a number to the caller
          Example 9876-8765-9876-0986 return 6
    """
    return "insert your code for Q1 above"

#Question 2
def First15DReverseList(cardno):
    """ Question 2 instructions
          This function will receive a 16 digits Visa Card Numbers delimited by - with 4 numberic numbers
          in between, you may assume the format 9999-9999-9999-999 has been validated before it is sent in
          This function will return a list containing the 0th element the 15 digit, 1st element the 14 digit
          and the last element is the first digit to the caller
          Example 1234-5678-9024-6813 return [1,8,6,4,2,0,9,8,7,6,5,4,3,2,1]
    """

    return "insert your code for Q2 above"

#Question 3
def x2ToOddDigits(inlist):
    """ Question 3 instructions
          This function will receive a list (inlist) containing numbers
          you are required to Multiply the digits in odd positions (1, 3, 5, etc.) by 2
          the change will apply directly on inlist, hence this function will not return caller any value
          For example before calling the function, if the inlist is [1,2,3,4,5,6]
          after this function is called, inlist becomes [2,2,6,4,10,6]
    """
    return "insert your code for Q3 above"
        
#Question 4        
def normalise9(inlist):
    """ Question 4 instructions
          This function will receive a list (inlist) containing numbers
          you are required prepare a new list and transfer each element in inlist to this new list
          with one constraint : subtract 9 to any element if it is higher than 9
          This function will return the new list to the caller.
          For example if this function receive inlist as [2,2,6,4,10,6]
          after the call, inlist will still be [2,2,6,4,10,6] but it will return [2,2,6,4,1,6] to the caller
    """
    return "insert your code for Q4 above"

#Question 5
def findlastdigit(norm15Dlist):
    """ Question 5 instructions
          This function will receive a list (norm15Dlist) containing numbers
          This function add all the numbers in the list together and find
          the number that you would need to add to get a multiple of 10 (Modulo 10)
          you are required to return this number to the caller
          For example if this function receive inlist as [2,2,6,4,1,6]
          2+2+6+4+1+6 = 21
          21 + 9 = 30 (30 is the multiple of 10) 
          this function will return 9 to the caller
    """
    return "insert your code for Q5 above"

#Question 6
def validateVisa(cardno):
    """ Question 6 instructions
    How to validate a Credit Card Number?
    Most credit card number can be validated using the Luhn algorithm, which is more or a less a glorified Modulo 10 formula!

    The Luhn Formula:
    Drop the last digit from the number. The last digit is what we want to check against
    Reverse the numbers
    Multiply the digits in odd positions (1, 3, 5, etc.) by 2 and subtract 9 to all any result higher than 9
    Add all the numbers together
    The check digit (the last number of the card) is the amount that you would need to add to get a multiple of 10 (Modulo 10)

    Luhn Example:
    Step																	Total
    Original Number:	4	5	5	6	7	3	7	5	8	6	8	9	9	8	5	5	
    Drop the last digit:	4	5	5	6	7	3	7	5	8	6	8	9	9	8	5		
    Reverse the digits:	5	8	9	9	8	6	8	5	7	3	7	6	5	5	4		
    Multiple odd digits by 2:	10	8	18	9	16	6	16	5	14	3	14	6	10	5	8		
    Subtract 9 to numbers over 9:	1	8	9	9	7	6	7	5	5	3	5	6	1	5	8		
    Add all numbers:	1	8	9	9	7	6	7	5	5	3	5	6	1	5	8		85
    Mod 10:	85 modulo 10 = 5 (last digit of card)

    you are required to make use of the functions you built for Question 1 to 5 and make this function
    validate any visacard number send in via "cardno". If the cardno is valid, this function will return True;
    if not valid, return False to the caller.
    """
    return "insert your code for Q6 above"


if __name__ == "__main__":
    """ You may move this line down to perform testing after complete each function       
  #Test for Question 1   
    print(1)
    print(LastDigit("4566-7375-8689-9855"))   #  should return 5
    print(LastDigit("4566-7375-8689-9857"))   #  should return 7


    #Test for Question 2
    print(2)
    revlist=First15DReverseList("4566-7375-8689-9855")
    print(revlist) # should return [5, 8, 9, 9, 8, 6, 8, 5, 7, 3, 7, 6, 6, 5, 4]

    #Test for Question 3
    print(3)
    klist=[5, 8, 9, 9, 8, 6, 8, 5, 7, 3, 7, 6, 6, 5, 4]
    x2ToOddDigits(klist)
    print(klist) # should return [10, 8, 18, 9, 16, 6, 16, 5, 14, 3, 14, 6, 10, 5, 8]

    #Test for Question 4
    print(4)
    finList =  normalise9([10, 8, 18, 9, 16, 6, 16, 5, 14, 3, 14, 6, 10, 5, 8])
    print(revlist) # should retuen [5, 8, 9, 9, 8, 6, 8, 5, 7, 3, 7, 6, 6, 5, 4]
    print(finList) # should return [1, 8, 9, 9, 7, 6, 7, 5, 5, 3, 5, 6, 1, 5, 8]

    #Test for Question 5
    print(5)
    print(findlastdigit([2,2,6,4,1,6])) #should print 9
    print(findlastdigit([9,2,6,4,1,6])) #should print 2   

    #Test For validateVisa
    print("This is a test for validateVisa....")
    OrignalVisa="4556-7375-8689-9855"
    if validateVisa( OrignalVisa):
        print(f'{OrignalVisa} is a Valid Card')    # This should be printed
    else:
        print(f'{OrignalVisa} is a Invalid Card')
    anotherVisa= "4566-7375-8689-9855"
    if validateVisa(anotherVisa):  #"4566-7375-8689-9855"
        print(f'{anotherVisa} is a Valid Card')  
    else:
        print(f'{anotherVisa} is a Invalid Card')  # This should be printed
        
        
    """
